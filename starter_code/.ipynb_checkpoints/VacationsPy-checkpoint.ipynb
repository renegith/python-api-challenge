# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %%
#Store Part I results into DataFrame
#Load the csv exported in Part I to a DataFrame
weather_df = pd.read_csv("../output_data/Cities.csv")
weather_df
# Out:
#      City_ID         City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0    ostrovnoy           2      RU  1558378754        72  68.05
# 1          1    mahebourg          75      MU  1558378503        74 -20.41
# 2          2      qaanaaq          25      GL  1558378755        73  77.48
# 3          3       zhuhai           0      CN  1558378755        39  40.71
# 4          4    cape town          20      ZA  1558378755        76 -33.93
# ..       ...          ...         ...     ...         ...       ...    ...
# 543      543       yabrud           0      SY  1558378840        32  33.97
# 544      544      paraiso           5      MX  1558378898         4  24.01
# 545      545      veraval           0      FR  1558378898        62  49.65
# 546      546  novyy urgal         100      RU  1558378899        93  51.07
# 547      547      tongren           4      CN  1558378899        64  27.72
#
#         Lng  Max Temp  Wind Speed
# ...

# %%
#Humidity Heatmap
#Configure gmaps.
gmaps.configure(api_key = "AIzaSyB6m9lD480UOwsUt5Dd1oj-2stw3dr8lvw")
#Use the Lat and Lng as locations and Humidity as the weight.
locations = weather_df[["Lat", "Lng"]]
humidity = weather_df["Humidity"]
#Add Heatmap layer to map.
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=10, point_radius=1)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Create new DataFrame fitting weather criteria
#Narrow down the cities to fit weather conditions.
#Drop any rows will null values.
new_weather = weather_df.loc[(weather_df["Wind Speed"] < 10) & (weather_df["Cloudiness"] > 10) & (weather_df["Cloudiness"] < 40) & (weather_df["Max Temp"] > 60) & (weather_df["Max Temp"] < 80)].dropna()
new_weather
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 22        22         ambon          11      FR  1558378758        93  47.55
# 25        25       kantang          20      TH  1558378759        94   7.42
# 44        44  puerto ayora          26      EC  1558378762        86  -0.74
# 69        69       fortuna          20      ES  1558378767        77  38.18
# 86        86    nikolskoye          20      RU  1558378770        56  59.70
# 153      153    porto novo          20      BR  1558378783        53 -23.68
# 201      201        luanda          20      AO  1558378792        78  -8.83
# 211      211       labuhan          18      ID  1558378794        86  -2.54
# 215      215       le port          25      FR  1558378795        64  42.87
# 221      221        marawi          12      PH  1558378796        93   8.00
# 223      223      koronowo          20      PL  1558378736        60  53.31
# ...

# %%
#Hotel Map
#Store into variable named hotel_df.
hotel_df = new_weather.loc[:,["City", "Country", "Max Temp", "Lat", "Lng"]]
#Add a "Hotel Name" column to the DataFrame.
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#              City Country  Max Temp    Lat     Lng Hotel Name
# 22          ambon      FR     64.99  47.55   -2.56
# 25        kantang      TH     78.80   7.42   99.52
# 44   puerto ayora      EC     79.00  -0.74  -90.35
# 69        fortuna      ES     69.80  38.18   -1.13
# 86     nikolskoye      RU     69.01  59.70   30.79
# 153    porto novo      BR     77.00 -23.68  -45.44
# 201        luanda      AO     78.80  -8.83   13.24
# 211       labuhan      ID     75.48  -2.54  115.51
# 215       le port      FR     60.01  42.87    1.37
# 221        marawi      PH     77.00   8.00  124.29
# 223      koronowo      PL     71.01  53.31   17.94
# 234        katobu      ID     75.66  -4.94  122.53
# 237      andradas      BR     79.00 -22.07  -46.57
# 303        yulara      AU     62.60 -25.24  130.99
# 310         airai      TL     75.12  -8.93  125.41
# 360   fort nelson      CA     68.00  58.81 -122.69
# 381      quanzhou      CN     69.80  24.90  118.59
# ...

# %%
#Set parameters to search for hotels with 5000 meters.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {"radius": 5000, "type":"lodging", "keyword":"hotel", "key":"AIzaSyB6m9lD480UOwsUt5Dd1oj-2stw3dr8lvw"}
#Hit the Google Places API for each city's coordinates.
for index, row in hotel_df.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
    city_name = row["City"]
    params["location"] = f"{lat},{lng}"
    response = requests.get(base_url, params=params).json()
    results = response['results']
    try:
        print(f"Closest hotel in {city_name} is {results[0]['name']}.")
        hotel_df.loc[index, "Hotel Name"] = results[0]['name']
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")     
    print("-------------------------------------")
#Store the first Hotel result into the DataFrame.
hotel_df
#Plot markers on top of the heatmap.
# Out:
# Closest hotel in ambon is Camping Cromenach Ambon Damgan Beach.
# -------------------------------------
# Missing field/result... skipping.
# -------------------------------------
# Closest hotel in puerto ayora is Finch Bay Galapagos Hotel.
# -------------------------------------
# Closest hotel in fortuna is Balneario de Leana.
# -------------------------------------
# Missing field/result... skipping.
# -------------------------------------
# Closest hotel in porto novo is Hotel Pousada Paradise.
# -------------------------------------
# Closest hotel in luanda is EPIC SANA Luanda.
# -------------------------------------
# Missing field/result... skipping.
# -------------------------------------
# Closest hotel in le port is Maison Esmeralda Chambres d'Hotes & Gite.
# -------------------------------------
# Closest hotel in marawi is Marawi Resort Hotel.
# -------------------------------------
# Missing field/result... skipping.
# -------------------------------------
# ...

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig.add_layer(markers)
# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
